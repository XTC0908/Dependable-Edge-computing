# %%
import osmnx as ox
# %matplotlib inline

# %%
location_point = (59.34, 18.07)
G = ox.graph_from_point(location_point, distance=500, simplify=False, network_type='drive')
G = ox.project_graph(G)
#G = ox.simplify_graph(G)
fig, ax = ox.plot_graph(G)

# %%
G2.nodes['372856832']
# Out:
# {'highway': 'nan',
#  'osmid': '372856832',
#  'x': '333844.0885579556',
#  'y': '6581878.316234643',
#  'lon': '18.078231',
#  'lat': '59.3428782'}

# %%
import networkx as nx
G2 = ox.load_graphml('demo.graphml')
fig, ax = ox.plot_graph(G2)

# %%
E = ox.graph_to_gdfs(G2, nodes=False, fill_edge_geometry=True)
n, s, e, w = E.total_bounds

# %%
G2.edges(keys=False, data=False)
# Out:
# OutMultiEdgeDataView([(372856832, 1734187231), (372856832, 1734187227), (372856832, 169807), (372856833, 372855649), (372856833, 222143621), (1513160716, 169838), (222113805, 222113806), (222113806, 1525463158), (1513160719, 1486022371), (1513160719, 271319783), (222113807, 1525463151), (1734187026, 1734187027), (1734187027, 2219802962), (1734187027, 475902911), (1734187028, 1362013639), (1734187028, 5418184407), (1734187029, 1386747199), (1734187029, 1734187030), (1409026070, 1363066796), (1734187030, 1734187031), (1734187031, 5418184411), (1734187032, 5418184412), (1734187034, 32911183), (1734187033, 5418184413), (1734187035, 1734187036), (1734187036, 1393926007), (1734187036, 172605), (1734187036, 1734187037), (1734187037, 5533753306), (1734187038, 1734187041), (1734187041, 1734187043), (1734187043, 2357517), (1734187043, 410525079), (1734187043, 5533753307), (1734187045, 1469802267), (1734187045, 5533753308), (1734187046, 1734187047), (1734187047, 6034498386), (2334787625, 249238
# ...
