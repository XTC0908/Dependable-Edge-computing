# %%
import osmnx as ox
import networkx as nx
# %matplotlib inline

# %%
location_point = (59.34, 18.07)
G = ox.graph_from_point(location_point, distance=500, simplify=False, network_type='drive')
G = ox.project_graph(G)
#G = ox.simplify_graph(G)
fig, ax = ox.plot_graph(G)

# %%
nl = list(G.node)
nc = ['r' if (i == 1 or i == 72) else 'b' for i in range(len(nl))]

# %%
fig, ax = ox.plot_graph(G, node_color=nc)

# %%
l_max = 0
u_max = 0
v_max = 0
for u, v, d in G.edges(keys=False, data=True):
    if u == 5665142932 and v == 6034517158:
        print('good')
    if u == 6034517158 and v == 5665142932:
        print('goo2')
# Out:
# good

# %%
G.node[1734187038]
# Out:
# {'highway': nan,
#  'osmid': '1734187038',
#  'x': 333583.238725226,
#  'y': 6581303.567919869,
#  'lon': 18.0740947,
#  'lat': 59.3376208}

# %%
G.remove_edge(6034517158, 5665142932)
